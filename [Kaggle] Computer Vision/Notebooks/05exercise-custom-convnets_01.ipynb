# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),
    
    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_1.hint()
q_1.solution()
# Out:
# Hint: You should add two `Conv2D` layers and then a `MaxPool2D` layer. They will be just the same as the other layers in the model, except for some of the parameter values.
# Solution:
# ```python
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     # Block One
#     layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
#                   input_shape=[128, 128, 3]),
#     layers.MaxPool2D(),
#
#     # Block Two
#     layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Three
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Head
#     layers.Flatten(),
#     layers.Dense(6, activation='relu'),
#     layers.Dropout(0.2),
#     layers.Dense(1, activation='sigmoid'),
# ])
#
# ```

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()
# Out:
# Hint: This is a *binary* classification problem.
# Solution:
# ```python
#
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 38s 346ms/step - loss: 0.6786 - binary_accuracy: 0.5749 - val_loss: 0.6651 - val_binary_accuracy: 0.6032
# Epoch 2/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6660 - binary_accuracy: 0.5994 - val_loss: 0.6544 - val_binary_accuracy: 0.6080
# Epoch 3/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6590 - binary_accuracy: 0.6078 - val_loss: 0.6515 - val_binary_accuracy: 0.6242
# Epoch 4/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6483 - binary_accuracy: 0.6168 - val_loss: 0.6403 - val_binary_accuracy: 0.6181
# Epoch 5/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6405 - binary_accuracy: 0.6312 - val_loss: 0.6268 - val_binary_accuracy: 0.6498
# Epoch 6/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6245 - binary_accuracy: 0.6406 - val_loss: 0.6195 - val_binary_accuracy: 0.6525
# Epoch 7/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6171 - binary_accuracy: 0.6449 - val_loss: 0.6162 - val_binary_accuracy: 0.6478
# Epoch 8/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6034 - binary_accuracy: 0.6674 - val_loss: 0.5987 - val_binary_accuracy: 0.6737
# Epoch 9/50
# 80/80 [==============================] - 4s 46ms/step - loss: 0.5944 - binary_accuracy: 0.6664 - val_loss: 0.5916 - val_binary_accuracy: 0.6828
# Epoch 10/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5765 - binary_accuracy: 0.6828 - val_loss: 0.5823 - val_binary_accuracy: 0.6941
# Epoch 11/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5646 - binary_accuracy: 0.6940 - val_loss: 0.5659 - val_binary_accuracy: 0.7038
# Epoch 12/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5463 - binary_accuracy: 0.7155 - val_loss: 0.5571 - val_binary_accuracy: 0.7076
# Epoch 13/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5278 - binary_accuracy: 0.7151 - val_loss: 0.5340 - val_binary_accuracy: 0.7307
# Epoch 14/50
# 80/80 [==============================] - 3s 38ms/step - loss: 0.5084 - binary_accuracy: 0.7286 - val_loss: 0.5101 - val_binary_accuracy: 0.7507
# Epoch 15/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4799 - binary_accuracy: 0.7628 - val_loss: 0.5047 - val_binary_accuracy: 0.7448
# Epoch 16/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4604 - binary_accuracy: 0.7725 - val_loss: 0.4998 - val_binary_accuracy: 0.7466
# Epoch 17/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4305 - binary_accuracy: 0.7936 - val_loss: 0.4609 - val_binary_accuracy: 0.7828
# Epoch 18/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.4093 - binary_accuracy: 0.8056 - val_loss: 0.4440 - val_binary_accuracy: 0.7921
# Epoch 19/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3847 - binary_accuracy: 0.8261 - val_loss: 0.4399 - val_binary_accuracy: 0.8012
# Epoch 20/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3549 - binary_accuracy: 0.8394 - val_loss: 0.4327 - val_binary_accuracy: 0.8070
# Epoch 21/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3416 - binary_accuracy: 0.8440 - val_loss: 0.4226 - val_binary_accuracy: 0.8169
# Epoch 22/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3239 - binary_accuracy: 0.8478 - val_loss: 0.4322 - val_binary_accuracy: 0.8173
# Epoch 23/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3143 - binary_accuracy: 0.8569 - val_loss: 0.4554 - val_binary_accuracy: 0.8123
# Epoch 24/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.3236 - binary_accuracy: 0.8472 - val_loss: 0.5654 - val_binary_accuracy: 0.7028
# Epoch 25/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2904 - binary_accuracy: 0.8700 - val_loss: 0.4553 - val_binary_accuracy: 0.8080
# Epoch 26/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2625 - binary_accuracy: 0.8835 - val_loss: 0.4840 - val_binary_accuracy: 0.7888
# Epoch 27/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2298 - binary_accuracy: 0.9023 - val_loss: 0.4620 - val_binary_accuracy: 0.8256
# Epoch 28/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2505 - binary_accuracy: 0.8874 - val_loss: 0.4406 - val_binary_accuracy: 0.8262
# Epoch 29/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2470 - binary_accuracy: 0.8915 - val_loss: 0.4466 - val_binary_accuracy: 0.8260
# Epoch 30/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2318 - binary_accuracy: 0.8968 - val_loss: 0.5959 - val_binary_accuracy: 0.8107
# Epoch 31/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2326 - binary_accuracy: 0.8958 - val_loss: 0.5039 - val_binary_accuracy: 0.8285
# Epoch 32/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1951 - binary_accuracy: 0.9224 - val_loss: 0.5443 - val_binary_accuracy: 0.8282
# Epoch 33/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1694 - binary_accuracy: 0.9316 - val_loss: 0.5854 - val_binary_accuracy: 0.8256
# Epoch 34/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1689 - binary_accuracy: 0.9320 - val_loss: 0.8259 - val_binary_accuracy: 0.7892
# Epoch 35/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1756 - binary_accuracy: 0.9304 - val_loss: 0.7663 - val_binary_accuracy: 0.8060
# Epoch 36/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1728 - binary_accuracy: 0.9302 - val_loss: 0.7818 - val_binary_accuracy: 0.8056
# Epoch 37/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1701 - binary_accuracy: 0.9293 - val_loss: 0.7964 - val_binary_accuracy: 0.8068
# Epoch 38/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1782 - binary_accuracy: 0.9273 - val_loss: 0.8392 - val_binary_accuracy: 0.8052
# Epoch 39/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1764 - binary_accuracy: 0.9279 - val_loss: 0.5361 - val_binary_accuracy: 0.8369
# Epoch 40/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1571 - binary_accuracy: 0.9338 - val_loss: 0.4566 - val_binary_accuracy: 0.8394
# Epoch 41/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1640 - binary_accuracy: 0.9304 - val_loss: 0.5534 - val_binary_accuracy: 0.8151
# Epoch 42/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1415 - binary_accuracy: 0.9429 - val_loss: 0.4893 - val_binary_accuracy: 0.8230
# Epoch 43/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.1243 - binary_accuracy: 0.9517 - val_loss: 0.5424 - val_binary_accuracy: 0.8016
# Epoch 44/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0992 - binary_accuracy: 0.9590 - val_loss: 0.5374 - val_binary_accuracy: 0.8464
# Epoch 45/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0835 - binary_accuracy: 0.9662 - val_loss: 0.6006 - val_binary_accuracy: 0.8450
# Epoch 46/50
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0715 - binary_accuracy: 0.9732 - val_loss: 0.7079 - val_binary_accuracy: 0.8493
# Epoch 47/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0600 - binary_accuracy: 0.9748 - val_loss: 0.7146 - val_binary_accuracy: 0.8525
# Epoch 48/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0550 - binary_accuracy: 0.9779 - val_loss: 0.7202 - val_binary_accuracy: 0.8454
# Epoch 49/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0550 - binary_accuracy: 0.9791 - val_loss: 0.7256 - val_binary_accuracy: 0.8483
# Epoch 50/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0532 - binary_accuracy: 0.9779 - val_loss: 0.7735 - val_binary_accuracy: 0.8466

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
