# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Reproducibility
def set_seed(seed=21019):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    #os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# %%
import glob
import librosa


data1 = []
labels1 = []
meta1 = []

aorticstenosis = glob.glob('/kaggle/input/15sdataforheartsound/aorticstenosis/*.wav')
mitral_regurgitation = glob.glob('/kaggle/input/15sdataforheartsound/mitral regurgitation/*.wav')
mitral_stenosis = glob.glob('/kaggle/input/15sdataforheartsound/mitral stenosis/*.wav')
mitral_valve_prolapse = glob.glob('/kaggle/input/15sdataforheartsound/mitral valve prolapse/*.wav')
normal = glob.glob('/kaggle/input/15sdataforheartsound/normal/*.wav')

SAMPLE_RATE = 1000
class_names = list(['Aortic Stenosis','Mitral Regurgitation','Mitral Stenosis','Mitral Valve Prolapse', 'Normal'])

for file_path in aorticstenosis:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(0)

for file_path in mitral_regurgitation:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(1)
    
for file_path in mitral_stenosis:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(2)
    
for file_path in mitral_valve_prolapse:
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(3)
    
for file_path in normal:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(4)
    
X = np.array(data1)
y = np.array(labels1)
print(f'Dataset Shape: {X.shape}, Labels Shape: {y.shape}')
# Out:
# Dataset Shape: (1000, 1125), Labels Shape: (1000,)

# %%
from sklearn.model_selection import train_test_split

# Perform train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# Perform train-validation split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=19)

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Activation, Add, GlobalAveragePooling1D
from tensorflow.keras.models import Model

# Define the input shape
dim = x_train[0].shape
input_shape = (dim[0], 1)

# Define the input tensor
inputs = Input(shape=input_shape)

# First Convolutional Block
x = Conv1D(64, 7, strides=2, padding='same', activation='relu')(inputs)
x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)
# Residual Block
residue = x


filters = 64
kernel_size = 3
steps = 1
# ResNet 34 Layers
block_repeats = (3, 4, 6, 3)

# Generalized Loop for Repetative Blocks
for i in block_repeats:
    for j in range(i):
        x = Conv1D(filters, kernel_size, strides=steps, padding='same', activation='relu')(x)
        x = Conv1D(filters, kernel_size, padding='same')(x)
        x = Add()([x, residue])
        x = Activation('relu')(x)
        residue = x
        steps=1
        
    filters=filters*2
    steps=2
    residue = Conv1D(filters, 1, strides=steps, padding='same', activation='relu')(x)

# Average Pooling
x = GlobalAveragePooling1D()(x)

# Output layer fully connected
outputs = Dense(len(class_names), activation='softmax')(x)

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1125, 1)]    0           []
#
#  conv1d (Conv1D)                (None, 563, 64)      512         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 282, 64)      0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 282, 64)      12352       ['max_pooling1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 282, 64)      12352       ['conv1d_1[0][0]']
#
#  add (Add)                      (None, 282, 64)      0           ['conv1d_2[0][0]',
#                                                                   'max_pooling1d[0][0]']
#
#  activation (Activation)        (None, 282, 64)      0           ['add[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 282, 64)      12352       ['activation[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 282, 64)      12352       ['conv1d_3[0][0]']
#
#  add_1 (Add)                    (None, 282, 64)      0           ['conv1d_4[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 282, 64)      0           ['add_1[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 282, 64)      12352       ['activation_1[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 282, 64)      12352       ['conv1d_5[0][0]']
#
#  add_2 (Add)                    (None, 282, 64)      0           ['conv1d_6[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 282, 64)      0           ['add_2[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 141, 128)     24704       ['activation_2[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 141, 128)     49280       ['conv1d_8[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 141, 128)     8320        ['activation_2[0][0]']
#
#  add_3 (Add)                    (None, 141, 128)     0           ['conv1d_9[0][0]',
#                                                                   'conv1d_7[0][0]']
#
#  activation_3 (Activation)      (None, 141, 128)     0           ['add_3[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 141, 128)     49280       ['activation_3[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 141, 128)     49280       ['conv1d_10[0][0]']
#
#  add_4 (Add)                    (None, 141, 128)     0           ['conv1d_11[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 141, 128)     0           ['add_4[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 141, 128)     49280       ['activation_4[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 141, 128)     49280       ['conv1d_12[0][0]']
#
#  add_5 (Add)                    (None, 141, 128)     0           ['conv1d_13[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 141, 128)     0           ['add_5[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 141, 128)     49280       ['activation_5[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 141, 128)     49280       ['conv1d_14[0][0]']
#
#  add_6 (Add)                    (None, 141, 128)     0           ['conv1d_15[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 141, 128)     0           ['add_6[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 71, 256)      98560       ['activation_6[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 71, 256)      196864      ['conv1d_17[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 71, 256)      33024       ['activation_6[0][0]']
#
#  add_7 (Add)                    (None, 71, 256)      0           ['conv1d_18[0][0]',
#                                                                   'conv1d_16[0][0]']
#
#  activation_7 (Activation)      (None, 71, 256)      0           ['add_7[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 71, 256)      196864      ['activation_7[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 71, 256)      196864      ['conv1d_19[0][0]']
#
#  add_8 (Add)                    (None, 71, 256)      0           ['conv1d_20[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 71, 256)      0           ['add_8[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 71, 256)      196864      ['activation_8[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 71, 256)      196864      ['conv1d_21[0][0]']
#
#  add_9 (Add)                    (None, 71, 256)      0           ['conv1d_22[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 71, 256)      0           ['add_9[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 71, 256)      196864      ['activation_9[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 71, 256)      196864      ['conv1d_23[0][0]']
#
#  add_10 (Add)                   (None, 71, 256)      0           ['conv1d_24[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 71, 256)      0           ['add_10[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 71, 256)      196864      ['activation_10[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 71, 256)      196864      ['conv1d_25[0][0]']
#
#  add_11 (Add)                   (None, 71, 256)      0           ['conv1d_26[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 71, 256)      0           ['add_11[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 71, 256)      196864      ['activation_11[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 71, 256)      196864      ['conv1d_27[0][0]']
#
#  add_12 (Add)                   (None, 71, 256)      0           ['conv1d_28[0][0]',
#                                                                   'activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 71, 256)      0           ['add_12[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 36, 512)      393728      ['activation_12[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 36, 512)      786944      ['conv1d_30[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 36, 512)      131584      ['activation_12[0][0]']
#
#  add_13 (Add)                   (None, 36, 512)      0           ['conv1d_31[0][0]',
#                                                                   'conv1d_29[0][0]']
#
#  activation_13 (Activation)     (None, 36, 512)      0           ['add_13[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 36, 512)      786944      ['activation_13[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 36, 512)      786944      ['conv1d_32[0][0]']
#
#  add_14 (Add)                   (None, 36, 512)      0           ['conv1d_33[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 36, 512)      0           ['add_14[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 36, 512)      786944      ['activation_14[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 36, 512)      786944      ['conv1d_34[0][0]']
#
#  add_15 (Add)                   (None, 36, 512)      0           ['conv1d_35[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 36, 512)      0           ['add_15[0][0]']
#
#  global_average_pooling1d (Glob  (None, 512)         0           ['activation_15[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 5)            2565        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,212,293
# Trainable params: 7,212,293
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


# Define the learning rate reduction callback
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',    # Monitor validation loss for learning rate reduction
    factor=0.5,            # Reduce learning rate by a factor
    patience=3,            # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6            # Minimum learning rate
)

# Define the model checkpoint callback to save the best model
checkpoint_callback = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

# Define the early stopping callback to stop training if validation loss does not improve
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# Train the model with history tapping (keeps data in a dictionary)
epochs = 100
batch_size = 64
history = model.fit(x_train, y_train, 
                    validation_data=(x_val,y_val),
                    epochs=epochs, 
                    batch_size=batch_size,
                    callbacks=[lr_callback,checkpoint_callback,early_stopping_callback],
                    shuffle=True
                   )

# Evaluate the model
best_model = tf.keras.models.load_model('best_model.h5')
loss, accuracy = best_model.evaluate(x_test, y_test)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/100
# 10/10 [==============================] - 22s 178ms/step - loss: 3.5062 - accuracy: 0.2156 - val_loss: 1.6062 - val_accuracy: 0.2438 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 1s 53ms/step - loss: 1.6099 - accuracy: 0.2297 - val_loss: 1.6077 - val_accuracy: 0.1750 - lr: 0.0010
# Epoch 3/100
# 10/10 [==============================] - 1s 92ms/step - loss: 1.6011 - accuracy: 0.2438 - val_loss: 1.5804 - val_accuracy: 0.1625 - lr: 0.0010
# Epoch 4/100
# 10/10 [==============================] - 1s 95ms/step - loss: 1.5337 - accuracy: 0.3063 - val_loss: 1.5012 - val_accuracy: 0.2313 - lr: 0.0010
# Epoch 5/100
# 10/10 [==============================] - 0s 50ms/step - loss: 1.3706 - accuracy: 0.3516 - val_loss: 1.8363 - val_accuracy: 0.2750 - lr: 0.0010
# Epoch 6/100
# 10/10 [==============================] - 1s 94ms/step - loss: 1.3458 - accuracy: 0.3812 - val_loss: 1.4403 - val_accuracy: 0.3375 - lr: 0.0010
# Epoch 7/100
# 10/10 [==============================] - 1s 92ms/step - loss: 1.3406 - accuracy: 0.4234 - val_loss: 1.4001 - val_accuracy: 0.3063 - lr: 0.0010
# Epoch 8/100
# 10/10 [==============================] - 0s 50ms/step - loss: 1.3024 - accuracy: 0.4047 - val_loss: 1.4873 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 9/100
# 10/10 [==============================] - 2s 195ms/step - loss: 1.2754 - accuracy: 0.4219 - val_loss: 1.3733 - val_accuracy: 0.4062 - lr: 0.0010
# Epoch 10/100
# 10/10 [==============================] - 1s 54ms/step - loss: 1.1686 - accuracy: 0.4391 - val_loss: 1.3827 - val_accuracy: 0.3625 - lr: 0.0010
# Epoch 11/100
# 10/10 [==============================] - 1s 90ms/step - loss: 1.1993 - accuracy: 0.5047 - val_loss: 1.2246 - val_accuracy: 0.4125 - lr: 0.0010
# Epoch 12/100
# 10/10 [==============================] - 1s 93ms/step - loss: 1.0974 - accuracy: 0.4891 - val_loss: 1.0865 - val_accuracy: 0.4500 - lr: 0.0010
# Epoch
100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0809 - accuracy: 0.9750 - val_loss: 0.2610 - val_accuracy: 0.9250 - lr: 1.2500e-04
# Epoch 53/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0873 - accuracy: 0.9750 - val_loss: 0.1994 - val_accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 54/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0800 - accuracy: 0.9734 - val_loss: 0.1929 - val_accuracy: 0.9250 - lr: 1.2500e-04
# Epoch 55/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0884 - accuracy: 0.9688 - val_loss: 0.2412 - val_accuracy: 0.9250 - lr: 1.2500e-04
# Epoch 56/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1141 - accuracy: 0.9594 - val_loss: 0.1751 - val_accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 57/100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0768 - accuracy: 0.9719 - val_loss: 0.2152 - val_accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 58/100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0683 - accuracy: 0.9812 - val_loss: 0.2724 - val_accuracy: 0.9438 - lr: 1.2500e-04
# Epoch 59/100
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0552 - accuracy: 0.9797 - val_loss: 0.2953 - val_accuracy: 0.9375 - lr: 1.2500e-04
# Epoch 60/100
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0627 - accuracy: 0.9797 - val_loss: 0.2600 - val_accuracy: 0.9500 - lr: 6.2500e-05
# Epoch 61/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0490 - accuracy: 0.9859 - val_loss: 0.2689 - val_accuracy: 0.9438 - lr: 6.2500e-05
# Epoch 62/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0416 - accuracy: 0.9875 - val_loss: 0.2896 - val_accuracy: 0.9500 - lr: 6.2500e-05
# Epoch 63/100
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0384 - accuracy: 0.9859 - val_loss: 0.3034 - val_accuracy: 0.9500 - lr: 3.1250e-05
# Epoch 64/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0363 - accuracy: 0.9891 - val_loss: 0.3132 - val_accuracy: 0.9500 - lr: 3.1250e-05
# Epoch 65/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0349 - accuracy: 0.9906 - val_loss: 0.3223 - val_accuracy: 0.9500 - lr: 3.1250e-05
# Epoch 66/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0340 - accuracy: 0.9906 - val_loss: 0.3215 - val_accuracy: 0.9500 - lr: 1.5625e-05
# 7/7 [==============================] - 1s 32ms/step - loss: 0.2473 - accuracy: 0.9700
# Test loss: 0.2473
# Test accuracy: 0.9700

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Get the true labels and predicted probabilities for the test data
# Make predictions
predictions = best_model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=1)

# Generate the classification report
report = classification_report(y_test, predicted_classes, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# 7/7 [==============================] - 1s 8ms/step
# Classification Report:
#                         precision    recall  f1-score   support
#
#       Aortic Stenosis       0.98      1.00      0.99        41
#  Mitral Regurgitation       0.98      0.98      0.98        44
#       Mitral Stenosis       0.97      0.91      0.94        34
# Mitral Valve Prolapse       0.92      0.95      0.94        38
#                Normal       1.00      1.00      1.00        43
#
#              accuracy                           0.97       200
#             macro avg       0.97      0.97      0.97       200
#          weighted avg       0.97      0.97      0.97       200

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
