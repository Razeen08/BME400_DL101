# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Reproducibility
def set_seed(seed=21019):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    #os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# %%
import glob
import librosa


data1 = []
labels1 = []
meta1 = []

aorticstenosis = glob.glob('/kaggle/input/15sdataforheartsound/aorticstenosis/*.wav')
mitral_regurgitation = glob.glob('/kaggle/input/15sdataforheartsound/mitral regurgitation/*.wav')
mitral_stenosis = glob.glob('/kaggle/input/15sdataforheartsound/mitral stenosis/*.wav')
mitral_valve_prolapse = glob.glob('/kaggle/input/15sdataforheartsound/mitral valve prolapse/*.wav')
normal = glob.glob('/kaggle/input/15sdataforheartsound/normal/*.wav')

SAMPLE_RATE = 1000
class_names = list(['Aortic Stenosis','Mitral Regurgitation','Mitral Stenosis','Mitral Valve Prolapse', 'Normal'])

for file_path in aorticstenosis:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(0)

for file_path in mitral_regurgitation:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(1)
    
for file_path in mitral_stenosis:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(2)
    
for file_path in mitral_valve_prolapse:
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(3)
    
for file_path in normal:   
    #print(file_path)
    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
    signal=np.array(signal)
    data1.append(signal)
    labels1.append(4)
    
X = np.array(data1)
y = np.array(labels1)
print(f'Dataset Shape: {X.shape}, Labels Shape: {y.shape}')
# Out:
# Dataset Shape: (1000, 1125), Labels Shape: (1000,)

# %%
from sklearn.model_selection import train_test_split

# Perform train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

# Perform train-validation split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=19)

# %%
import pickle

# Save the arrays
with open('data.pkl', 'wb') as f:
    data = {
        'x_train': x_train,
        'x_test': x_test,
        'x_val': x_val,
        'y_train': y_train,
        'y_test': y_test,
        'y_val': y_val
    }
    pickle.dump(data, f)

# %%
import pickle

# Load the arrays from the pickle file
with open('data.pkl', 'rb') as f:
    data = pickle.load(f)

x_train = data['x_train']
x_test = data['x_test']
x_val = data['x_val']
y_train = data['y_train']
y_test = data['y_test']
y_val = data['y_val']

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Activation, Add, GlobalAveragePooling1D
from tensorflow.keras.models import Model

# Define the input shape
dim = x_train[0].shape
input_shape = (dim[0], 1)

# Define the input tensor
inputs = Input(shape=input_shape)

# First Convolutional Block
x = Conv1D(64, 7, strides=2, padding='same', activation='relu')(inputs)
x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)
# Residual Block
residue = x


filters = 64
kernel_size = 3
steps = 1
# ResNet 34 Layers
block_repeats = (3, 4, 6, 3)

# Generalized Loop for Repetative Blocks
for i in block_repeats:
    for j in range(i):
        x = Conv1D(filters, kernel_size, strides=steps, padding='same', activation='relu')(x)
        x = Conv1D(filters, kernel_size, padding='same')(x)
        x = Add()([x, residue])
        x = Activation('relu')(x)
        residue = x
        steps=1
        
    filters=filters*2
    steps=2
    residue = Conv1D(filters, 1, strides=steps, padding='same', activation='relu')(x)

# Average Pooling
x = GlobalAveragePooling1D()(x)

# Output layer fully connected
outputs = Dense(len(class_names), activation='softmax')(x)

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1125, 1)]    0           []
#
#  conv1d (Conv1D)                (None, 563, 64)      512         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 282, 64)      0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 282, 64)      12352       ['max_pooling1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 282, 64)      12352       ['conv1d_1[0][0]']
#
#  add (Add)                      (None, 282, 64)      0           ['conv1d_2[0][0]',
#                                                                   'max_pooling1d[0][0]']
#
#  activation (Activation)        (None, 282, 64)      0           ['add[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 282, 64)      12352       ['activation[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 282, 64)      12352       ['conv1d_3[0][0]']
#
#  add_1 (Add)                    (None, 282, 64)      0           ['conv1d_4[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 282, 64)      0           ['add_1[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 282, 64)      12352       ['activation_1[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 282, 64)      12352       ['conv1d_5[0][0]']
#
#  add_2 (Add)                    (None, 282, 64)      0           ['conv1d_6[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 282, 64)      0           ['add_2[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 141, 128)     24704       ['activation_2[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 141, 128)     49280       ['conv1d_8[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 141, 128)     8320        ['activation_2[0][0]']
#
#  add_3 (Add)                    (None, 141, 128)     0           ['conv1d_9[0][0]',
#                                                                   'conv1d_7[0][0]']
#
#  activation_3 (Activation)      (None, 141, 128)     0           ['add_3[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 141, 128)     49280       ['activation_3[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 141, 128)     49280       ['conv1d_10[0][0]']
#
#  add_4 (Add)                    (None, 141, 128)     0           ['conv1d_11[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 141, 128)     0           ['add_4[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 141, 128)     49280       ['activation_4[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 141, 128)     49280       ['conv1d_12[0][0]']
#
#  add_5 (Add)                    (None, 141, 128)     0           ['conv1d_13[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 141, 128)     0           ['add_5[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 141, 128)     49280       ['activation_5[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 141, 128)     49280       ['conv1d_14[0][0]']
#
#  add_6 (Add)                    (None, 141, 128)     0           ['conv1d_15[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 141, 128)     0           ['add_6[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 71, 256)      98560       ['activation_6[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 71, 256)      196864      ['conv1d_17[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 71, 256)      33024       ['activation_6[0][0]']
#
#  add_7 (Add)                    (None, 71, 256)      0           ['conv1d_18[0][0]',
#                                                                   'conv1d_16[0][0]']
#
#  activation_7 (Activation)      (None, 71, 256)      0           ['add_7[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 71, 256)      196864      ['activation_7[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 71, 256)      196864      ['conv1d_19[0][0]']
#
#  add_8 (Add)                    (None, 71, 256)      0           ['conv1d_20[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 71, 256)      0           ['add_8[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 71, 256)      196864      ['activation_8[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 71, 256)      196864      ['conv1d_21[0][0]']
#
#  add_9 (Add)                    (None, 71, 256)      0           ['conv1d_22[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 71, 256)      0           ['add_9[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 71, 256)      196864      ['activation_9[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 71, 256)      196864      ['conv1d_23[0][0]']
#
#  add_10 (Add)                   (None, 71, 256)      0           ['conv1d_24[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 71, 256)      0           ['add_10[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 71, 256)      196864      ['activation_10[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 71, 256)      196864      ['conv1d_25[0][0]']
#
#  add_11 (Add)                   (None, 71, 256)      0           ['conv1d_26[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 71, 256)      0           ['add_11[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 71, 256)      196864      ['activation_11[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 71, 256)      196864      ['conv1d_27[0][0]']
#
#  add_12 (Add)                   (None, 71, 256)      0           ['conv1d_28[0][0]',
#                                                                   'activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 71, 256)      0           ['add_12[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 36, 512)      393728      ['activation_12[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 36, 512)      786944      ['conv1d_30[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 36, 512)      131584      ['activation_12[0][0]']
#
#  add_13 (Add)                   (None, 36, 512)      0           ['conv1d_31[0][0]',
#                                                                   'conv1d_29[0][0]']
#
#  activation_13 (Activation)     (None, 36, 512)      0           ['add_13[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 36, 512)      786944      ['activation_13[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 36, 512)      786944      ['conv1d_32[0][0]']
#
#  add_14 (Add)                   (None, 36, 512)      0           ['conv1d_33[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 36, 512)      0           ['add_14[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 36, 512)      786944      ['activation_14[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 36, 512)      786944      ['conv1d_34[0][0]']
#
#  add_15 (Add)                   (None, 36, 512)      0           ['conv1d_35[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 36, 512)      0           ['add_15[0][0]']
#
#  global_average_pooling1d (Glob  (None, 512)         0           ['activation_15[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 5)            2565        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,212,293
# Trainable params: 7,212,293
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


# Define the learning rate reduction callback
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',    # Monitor validation loss for learning rate reduction
    factor=0.6,            # Reduce learning rate by a factor
    patience=3,            # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6            # Minimum learning rate
)

# Define the model checkpoint callback to save the best model
checkpoint_callback = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

# Define the early stopping callback to stop training if validation loss does not improve
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# Train the model with history tapping (keeps data in a dictionary)
epochs = 100
batch_size = 100
history = model.fit(x_train, y_train, 
                    validation_data=(x_val,y_val),
                    epochs=epochs, 
                    batch_size=batch_size,
                    callbacks=[lr_callback,checkpoint_callback,early_stopping_callback],
                    shuffle=True
                   )

# Evaluate the model
best_model = tf.keras.models.load_model('best_model.h5')
loss, accuracy = best_model.evaluate(x_test, y_test)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/100
# 7/7 [==============================] - 23s 364ms/step - loss: 3.0141 - accuracy: 0.1984 - val_loss: 1.6071 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 0s 67ms/step - loss: 1.5932 - accuracy: 0.1937 - val_loss: 1.6651 - val_accuracy: 0.1625 - lr: 0.0010
# Epoch 3/100
# 7/7 [==============================] - 0s 71ms/step - loss: 1.6040 - accuracy: 0.2484 - val_loss: 1.6098 - val_accuracy: 0.2062 - lr: 0.0010
# Epoch 4/100
# 7/7 [==============================] - 1s 74ms/step - loss: 1.6103 - accuracy: 0.2109 - val_loss: 1.6118 - val_accuracy: 0.1750 - lr: 0.0010
# Epoch 5/100
# 7/7 [==============================] - 0s 71ms/step - loss: 1.6074 - accuracy: 0.2156 - val_loss: 1.6118 - val_accuracy: 0.1750 - lr: 6.0000e-04
# Epoch 6/100
# 7/7 [==============================] - 1s 130ms/step - loss: 1.5988 - accuracy: 0.2453 - val_loss: 1.5998 - val_accuracy: 0.1750 - lr: 6.0000e-04
# Epoch 7/100
# 7/7 [==============================] - 1s 130ms/step - loss: 1.5313 - accuracy: 0.2516 - val_loss: 1.5302 - val_accuracy: 0.2125 - lr: 6.0000e-04
# Epoch 8/100
# 7/7 [==============================] - 1s 132ms/step - loss: 1.3698 - accuracy: 0.3031 - val_loss: 1.4084 - val_accuracy: 0.4125 - lr: 6.0000e-04
# Epoch 9/100
# 7/7 [==============================] - 1s 146ms/step - loss: 1.3233 - accuracy: 0.4703 - val_loss: 1.3451 - val_accuracy: 0.4688 - lr: 6.0000e-04
# Epoch 10/100
# 7/7 [==============================] - 0s 67ms/step - loss: 1.2362 - accuracy: 0.5063 - val_loss: 1.3846 - val_accuracy: 0.3812 - lr: 6.0000e-04
# Epoch 11/100
# 7/7 [==============================] - 1s 125ms/step - loss: 1.2501 - accuracy: 0.4672 - val_loss: 1.3049 - val_accuracy: 0.4750 - lr: 6.0000e-04
# Epoch 12/100
# 7/7 [==============================] - 1s 126ms/step - loss: 1.1784 - accuracy: 0.4797 - val_loss: 1.1868 - val_accuracy: 0.5562 - lr: 6.0000e-04
# Epoch 13/100
# 7/7 [==============================] - 1s 126ms/step - loss: 1.0290 - accuracy: 0.6078 - val_loss: 1.1420 - val_accuracy: 0.4750 - lr: 6.0000e-04
# Epoch 14/100
# 7/7 [==============================] - 1s 126ms/step - loss: 0.9429 - accuracy: 0.6172 - val_loss: 0.9816 - val_accuracy: 0.6187 - lr: 6.0000e-04
# Epoch 15/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.8496 - accuracy: 0.7000 - val_loss: 1.1684 - val_accuracy: 0.5312 - lr: 6.0000e-04
# Epoch 16/100
# 7/7 [==============================] - 2s 352ms/step - loss: 0.8021 - accuracy: 0.6984 - val_loss: 0.9729 - val_accuracy: 0.6313 - lr: 6.0000e-04
# Epoch 17/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.7578 - accuracy: 0.7328 - val_loss: 0.7152 - val_accuracy: 0.7937 - lr: 6.0000e-04
# Epoch 18/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.6646 - accuracy: 0.7969 - val_loss: 0.7301 - val_accuracy: 0.7375 - lr: 6.0000e-04
# Epoch 19/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.5960 - accuracy: 0.8062 - val_loss: 0.7258 - val_accuracy: 0.7375 - lr: 6.0000e-04
# Epoch 20/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4890 - accuracy: 0.8547 - val_loss: 1.1099 - val_accuracy: 0.5938 - lr: 6.0000e-04
# Epoch 21/100
# 7/7 [==============================] - 1s 128ms/step - loss: 0.6240 - accuracy: 0.7688 - val_loss: 0.6763 - val_accuracy: 0.8000 - lr: 3.6000e-04
# Epoch 22/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.4816 - accuracy: 0.8547 - val_loss: 0.5621 - val_accuracy: 0.8313 - lr: 3.6000e-04
# Epoch 23/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.4003 - accuracy: 0.8859 - val_loss: 0.5206 - val_accuracy: 0.8125 - lr: 3.6000e-04
# Epoch 24/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3581 - accuracy: 0.8766 - val_loss: 0.5671 - val_accuracy: 0.8500 - lr: 3.6000e-04
# Epoch 25/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.2988 - accuracy: 0.9219 - val_loss: 0.5321 - val_accuracy: 0.8188 - lr: 3.6000e-04
# Epoch 26/100
# 7/7 [==============================] - 1s 127ms/step - loss: 0.3175 - accuracy: 0.8984 - val_loss: 0.4367 - val_accuracy: 0.8438 - lr: 3.6000e-04
# Epoch 27/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2658 - accuracy: 0.9078 - val_loss: 0.4289 - val_accuracy: 0.8438 - lr: 3.6000e-04
# Epoch 28/100
# 7/7 [==============================] - 1s 127ms/step - loss: 0.2434 - accuracy: 0.9172 - val_loss: 0.4202 - val_accuracy: 0.8750 - lr: 3.6000e-04
# Epoch 29/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.2343 - accuracy: 0.9187 - val_loss: 0.4000 - val_accuracy: 0.8562 - lr: 3.6000e-04
# Epoch 30/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.2447 - accuracy: 0.9156 - val_loss: 0.3965 - val_accuracy: 0.8625 - lr: 3.6000e-04
# Epoch 31/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.2523 - accuracy: 0.9125 - val_loss: 0.3854 - val_accuracy: 0.8500 - lr: 3.6000e-04
# Epoch 32/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.2240 - accuracy: 0.9250 - val_loss: 0.3879 - val_accuracy: 0.8625 - lr: 3.6000e-04
# Epoch 33/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.2276 - accuracy: 0.9172 - val_loss: 0.4540 - val_accuracy: 0.8687 - lr: 3.6000e-04
# Epoch 34/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2323 - accuracy: 0.9234 - val_loss: 0.3636 - val_accuracy: 0.8687 - lr: 3.6000e-04
# Epoch 35/100
# 7/7 [==============================] - 1s 235ms/step - loss: 0.1903 - accuracy: 0.9422 - val_loss: 0.3512 - val_accuracy: 0.8625 - lr: 3.6000e-04
# Epoch 36/100
# 7/7 [==============================] - 1s 129ms/step - loss: 0.1588 - accuracy: 0.9500 - val_loss: 0.3057 - val_accuracy: 0.8750 - lr: 3.6000e-04
# Epoch 37/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.1431 - accuracy: 0.9516 - val_loss: 0.3473 - val_accuracy: 0.8938 - lr: 3.6000e-04
# Epoch 38/100
# 7/7 [==============================] - 1s 141ms/step - loss: 0.1556 - accuracy: 0.9531 - val_loss: 0.2695 - val_accuracy: 0.8938 - lr: 3.6000e-04
# Epoch 39/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.1286 - accuracy: 0.9547 - val_loss: 0.2773 - val_accuracy: 0.9000 - lr: 3.6000e-04
# Epoch 40/100
# 7/7 [==============================] - 0s 73ms/step - loss: 0.1487 - accuracy: 0.9484 - val_loss: 0.3287 - val_accuracy: 0.8938 - lr: 3.6000e-04
# Epoch 41/100
# 7/7 [==============================] - 1s 160ms/step - loss: 0.1394 - accuracy: 0.9453 - val_loss: 0.2601 - val_accuracy: 0.9125 - lr: 3.6000e-04
# Epoch 42/100
# 7/7 [==============================] - 0s 73ms/step - loss: 0.1285 - accuracy: 0.9641 - val_loss: 0.2815 - val_accuracy: 0.9187 - lr: 3.6000e-04
# Epoch 43/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.1395 - accuracy: 0.9516 - val_loss: 0.3462 - val_accuracy: 0.8875 - lr: 3.6000e-04
# Epoch 44/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.1172 - accuracy: 0.9625 - val_loss: 0.2462 - val_accuracy: 0.9125 - lr: 3.6000e-04
# Epoch 45/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0961 - accuracy: 0.9609 - val_loss: 0.2661 - val_accuracy: 0.9312 - lr: 3.6000e-04
# Epoch 46/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.1030 - accuracy: 0.9656 - val_loss: 0.2436 - val_accuracy: 0.9250 - lr: 3.6000e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.1215 - accuracy: 0.9469 - val_loss: 0.5504 - val_accuracy: 0.7937 - lr: 3.6000e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.2164 - accuracy: 0.9250 - val_loss: 0.5120 - val_accuracy: 0.8313 - lr: 3.6000e-04
# Epoch 49/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2265 - accuracy: 0.9250 - val_loss: 0.4664 - val_accuracy: 0.8750 - lr: 3.6000e-04
# Epoch 50/100
# 7/7 [==============================] - 0s 66ms/step - loss: 0.1568 - accuracy: 0.9469 - val_loss: 0.2533 - val_accuracy: 0.9125 - lr: 2.1600e-04
# Epoch 51/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.1122 - accuracy: 0.9688 - val_loss: 0.2565 - val_accuracy: 0.9187 - lr: 2.1600e-04
# Epoch 52/100
# 7/7 [==============================] - 1s 127ms/step - loss: 0.0889 - accuracy: 0.9719 - val_loss: 0.2306 - val_accuracy: 0.9000 - lr: 2.1600e-04
# Epoch 53/100
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0759 - accuracy: 0.9641 - val_loss: 0.1936 - val_accuracy: 0.9312 - lr: 2.1600e-04
# Epoch 54/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0598 - accuracy: 0.9797 - val_loss: 0.2249 - val_accuracy: 0.9250 - lr: 2.1600e-04
# Epoch 55/100
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0512 - accuracy: 0.9781 - val_loss: 0.1653 - val_accuracy: 0.9438 - lr: 2.1600e-04
# Epoch 56/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0416 - accuracy: 0.9859 - val_loss: 0.1853 - val_accuracy: 0.9375 - lr: 2.1600e-04
# Epoch 57/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0342 - accuracy: 0.9922 - val_loss: 0.1875 - val_accuracy: 0.9500 - lr: 2.1600e-04
# Epoch 58/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0275 - accuracy: 0.9937 - val_loss: 0.1791 - val_accuracy: 0.9438 - lr: 2.1600e-04
# Epoch 59/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0227 - accuracy: 0.9953 - val_loss: 0.1878 - val_accuracy: 0.9500 - lr: 1.2960e-04
# Epoch 60/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0226 - accuracy: 0.9937 - val_loss: 0.1936 - val_accuracy: 0.9500 - lr: 1.2960e-04
# Epoch 61/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.1597 - val_accuracy: 0.9563 - lr: 1.2960e-04
# Epoch 62/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 0.1985 - val_accuracy: 0.9438 - lr: 1.2960e-04
# Epoch 63/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0172 - accuracy: 0.9969 - val_loss: 0.1779 - val_accuracy: 0.9500 - lr: 1.2960e-04
# Epoch 64/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0156 - accuracy: 0.9969 - val_loss: 0.1829 - val_accuracy: 0.9500 - lr: 1.2960e-04
# Epoch 65/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.1952 - val_accuracy: 0.9375 - lr: 7.7760e-05
# Epoch 66/100
# 7/7 [==============================] - 0s 66ms/step - loss: 0.0123 - accuracy: 0.9969 - val_loss: 0.1974 - val_accuracy: 0.9438 - lr: 7.7760e-05
# Epoch 67/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.1817 - val_accuracy: 0.9438 - lr: 7.7760e-05
# Epoch 68/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.1848 - val_accuracy: 0.9500 - lr: 4.6656e-05
# Epoch 69/100
# 7/7 [==============================] - 0s 71ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.1951 - val_accuracy: 0.9500 - lr: 4.6656e-05
# Epoch 70/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.2028 - val_accuracy: 0.9375 - lr: 4.6656e-05
# Epoch 71/100
# 7/7 [==============================] - 0s 67ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.2021 - val_accuracy: 0.9312 - lr: 2.7994e-05
# 7/7 [==============================] - 1s 33ms/step - loss: 0.0591 - accuracy: 0.9850
# Test loss: 0.0591
# Test accuracy: 0.9850

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Get the true labels and predicted probabilities for the test data
# Make predictions
predictions = best_model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=1)

# Generate the classification report
report = classification_report(y_test, predicted_classes, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# 7/7 [==============================] - 1s 8ms/step
# Classification Report:
#                         precision    recall  f1-score   support
#
#       Aortic Stenosis       1.00      1.00      1.00        41
#  Mitral Regurgitation       0.98      0.98      0.98        44
#       Mitral Stenosis       0.94      1.00      0.97        34
# Mitral Valve Prolapse       1.00      0.97      0.99        38
#                Normal       1.00      0.98      0.99        43
#
#              accuracy                           0.98       200
#             macro avg       0.98      0.99      0.98       200
#          weighted avg       0.99      0.98      0.99       200

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="BuGn", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
